# %%
import matplotlib.pyplot as plt
import string

# Input
text = input("Enter the text to analyze: ")
text = text.lower()

# Remove punctuation
text = text.translate(str.maketrans('', '', string.punctuation))

#  Split + Count
words = text.split()
print(f"Total words: {len(words)}")

#  Frequency dictionary
freq = {}
for word in words:
    freq[word] = freq.get(word, 0) + 1

# Output frequencies
print(freq)

# Visualization
plt.bar(freq.keys(),freq.values(), color = "pink")
plt.title("Word Frequency")
plt.xlabel("Words")
plt.ylabel("Frequency")
plt.show()
# Out:
# Total words: 16
# {'python': 3, 'is': 2, 'great': 1, 'easy': 1, 'to': 2, 'learn': 1, 'and': 1, 'fun': 1, 'use': 1, 'i': 1, 'love': 1, 'learning': 1}
